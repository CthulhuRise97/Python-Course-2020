# %%
#Ejercicio 1
#Crear una lista con 1000 valores aleatorios que sigan una distribucion normal
#Crear un histograma mediante matplotlib con la lista de valores
#Crear un daigramde a caja donde se acumula el 50% de los valores medieante seaborn

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

lista_valores = np.random.randn(1000)
lista_valores
# Out:
# array([-3.94506487e-01, -4.92349495e-01,  1.28072102e+00, -1.70278663e+00,
#        -4.67527079e-01,  2.48355736e-01, -3.11739705e-01, -6.73637669e-01,
#         8.59734878e-03,  6.08902823e-01, -9.41940984e-02, -3.51898708e-01,
#        -1.00338746e+00,  1.61997797e-01, -6.94370176e-01,  2.60851567e-03,
#        -7.86304836e-01,  1.50436521e+00,  4.35509234e-02,  2.27329510e+00,
#         7.14231599e-01, -9.38196512e-01, -8.37591231e-01,  2.56671498e-01,
#         3.21817687e-01,  5.47529552e-01, -1.88016115e+00, -2.92552091e-01,
#        -8.39285929e-01, -4.45033795e-01, -2.18898005e-01, -2.09899156e+00,
#        -8.13652679e-01, -5.00194860e-01,  5.54923660e-01, -2.76896092e-01,
#        -8.79745189e-01,  7.61056469e-01, -8.42008002e-01,  1.62079058e+00,
#         1.94216058e-01,  2.64910896e-01, -1.33660520e+00, -2.25268660e-01,
#        -9.02982656e-01,  5.41012020e-01, -4.01336110e-01, -1.00306696e+00,
# ...

# %%
plt.hist(lista_valores)
# Out:
# (array([  7.,  35., 113., 179., 216., 219., 134.,  64.,  25.,   8.]),
#  array([-2.86668151, -2.26309354, -1.65950557, -1.0559176 , -0.45232963,
#          0.15125834,  0.7548463 ,  1.35843427,  1.96202224,  2.56561021,
#          3.16919818]),
#  <a list of 10 Patch objects>)

# %%
sns.boxplot(lista_valores)
